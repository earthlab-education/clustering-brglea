# %% [markdown]
# # Land cover classification at the Mississppi Delta
#
# In this notebook, you will use a k-means **unsupervised** clustering
# algorithm to group pixels by similar spectral signatures. **k-means** is
# an **exploratory** method for finding patterns in data. Because it is
# unsupervised, you don’t need any training data for the model. You also
# can’t measure how well it “performs” because the clusters will not
# correspond to any particular land cover class. However, we expect at
# least some of the clusters to be identifiable as different types of land
# cover.
#
# You will use the [harmonized Sentinal/Landsat multispectral
# dataset](https://lpdaac.usgs.gov/documents/1698/HLS_User_Guide_V2.pdf).
# You can access the data with an [Earthdata
# account](https://www.earthdata.nasa.gov/learn/get-started) and the
# [`earthaccess` library from
# NSIDC](https://github.com/nsidc/earthaccess):
#
# ## STEP 1: SET UP
#
# <link rel="stylesheet" type="text/css" href="./assets/styles.css"><div class="callout callout-style-default callout-titled callout-task"><div class="callout-header"><div class="callout-icon-container"><i class="callout-icon"></i></div><div class="callout-title-container flex-fill">Try It</div></div><div class="callout-body-container callout-body"><ol type="1">
# <li>Import all libraries you will need for this analysis</li>
# <li>Configure GDAL parameters to help avoid connection errors:
# <code>python      os.environ["GDAL_HTTP_MAX_RETRY"] = "5"      os.environ["GDAL_HTTP_RETRY_DELAY"] = "1"</code></li>
# </ol></div></div>

# %%
#Set up analysis Part 1 of 2
# Import libraries / packages

# Basic Packages
import os # Reproducible file paths
from glob import glob # Find files by pattern
import pathlib # Find the home folder
import pickle # Serializing/unserializing objects
import re # Regular expressions
import warnings # Filter warning messages
import zipfile # Work with zip files

# Imports for spatial data
import cartopy.crs as ccrs # CRSs (Coordinate Reference Systems)
import earthaccess # Access NASA data from the cloud
import earthpy as et # Spatial data analysis
import geopandas as gpd # Work with vector data
import geoviews as gv # Holoviews extension for data visualization
import hvplot.pandas # Interactive tabular and vector data
import hvplot.xarray # Interactive raster
import matplotlib.pyplot as plt # Overlay pandas and xarry plots, Overlay raster and vector data
import numpy as np # Adjust images 
import pandas as pd # Group and aggregate
import rioxarray as rxr # Work with geospatial raster data
import rioxarray.merge as rxrmerge # Merge rasters
import xarray as xr # Adjust images
from shapely.geometry import Polygon # Keep track of polygons geometry
from sklearn.cluster import KMeans # kmeans clustering
from sklearn.decomposition import PCA # Principal component analysis
from sklearn.metrics import silhouette_score # Performance metrics
from sklearn.preprocessing import StandardScaler # Standardize features
import seaborn as sns # Making pairplots for clustering 
from tqdm.notebook import tqdm # Visualize progress of iterative operations

# Import to be able to save plots
import holoviews as hv # be able to save hvplots

# Prevent GDAL from quitting due to momentary disruptions
os.environ["GDAL_HTTP_MAX_RETRY"] = "5"
os.environ["GDAL_HTTP_RETRY_DELAY"] = "1"

# Suppress third party warnings - 'ignore'
warnings.simplefilter('ignore')
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='91992ee0-9bef-4c74-a758-59c4c26e47c8'>
#   <div id="ff2bfba1-c710-4bc2-a238-40a4195097f6" data-root-id="91992ee0-9bef-4c74-a758-59c4c26e47c8" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# Set Up Analysis Part 2 of 2

# Define and create the project data directory
landcover_cluster_data_dir = os.path.join(
    pathlib.Path.home(),
    'earth-analytics',
    'land_cover_clustering'
)
# Make the directory
os.makedirs(landcover_cluster_data_dir, 
            # If directory already exists no error is raised
            exist_ok=True)

# Call the data directory to check its location
landcover_cluster_data_dir
# Out:
# '/Users/briannagleason/earth-analytics/land_cover_clustering'

# %% [markdown]
# Below you can find code for a caching **decorator** which you can use in
# your code. To use the decorator:
#
# ``` python
# @cached(key, override)
# def do_something(*args, **kwargs):
#     ...
#     return item_to_cache
# ```
#
# This decorator will **pickle** the results of running the
# `do_something()` function, and only run the code if the results don’t
# already exist. To override the caching, for example temporarily after
# making changes to your code, set `override=True`. Note that to use the
# caching decorator, you must write your own function to perform each
# task!

# %%
# Create a series of nested functions for caching a decorator
# to use later in code, Part 1 of 1

# Define function for the decorator
def cached(func_key, override=False):
    """
    A decorator to cache function results
    
    Parameters
    ==========
    key: str
      File basename used to save pickled results
    override: bool
      When True, re-compute even if the results are already stored
    """
    # Wrap caching function
    def compute_and_cache_decorator(compute_function):
        """
        Wrap the caching function
        
        Parameters
        ==========
        compute_function: function
          The function to run and cache results
        """
        # Computation and cache or load cached result
        def compute_and_cache(*args, **kwargs):
            """
            Perform a computation and cache, or load cached result.
            
            Parameters
            ==========
            args
              Positional arguments for the compute function
            kwargs
              Keyword arguments for the compute function
            """

            # Pickling and unpickling

            # Add an identifier from the particular function call
            # If 'cache_key' is found in kwargs
            if 'cache_key' in kwargs:
                # Create key by concatenating the 'func_key'
                key = '_'.join((func_key, kwargs['cache_key']))
            # If no'cache_key' is found in the kwargs    
            else:
                # Key will be set to the func_key
                key = func_key

            # Create file path for saving the cache
            path = os.path.join(
                # Specify root directory and location
                et.io.HOME, et.io.DATA_NAME, 'jars',
                # Pickle file named using 'key' 
                f'{key}.pickle')
            
            # Check if the cache exists already or override caching
            # If cache does not exist
            if not os.path.exists(path) or override:
                # Make jars directory if needed
                os.makedirs(os.path.dirname(path), 
                # If directory already exists no error is raised            
                exist_ok=True)
                # Run the compute function 
                result = compute_function(*args, **kwargs)
                # Pickle the object and save it in a file
                with open(path, 'wb') as file:
                    pickle.dump(result, file)

            # If cache already exists   
            else:
                # Unpickle the object
                with open(path, 'rb') as file:
                    # Load cached result
                    result = pickle.load(file)
            
            # Return innermost function for computation and cache    
            return result
        
        # Return wrap caching function
        return compute_and_cache
    
    # Return decorator to cache function results
    return compute_and_cache_decorator

# %% [markdown]
# ## STEP 2: STUDY SITE
#
# For this analysis, you will use a watershed from the [Water Boundary
# Dataset](https://www.usgs.gov/national-hydrography/access-national-hydrography-products),
# HU12 watersheds (WBDHU12.shp).
#
# <link rel="stylesheet" type="text/css" href="./assets/styles.css"><div class="callout callout-style-default callout-titled callout-task"><div class="callout-header"><div class="callout-icon-container"><i class="callout-icon"></i></div><div class="callout-title-container flex-fill">Try It</div></div><div class="callout-body-container callout-body"><ol type="1">
# <li>Download the Water Boundary Dataset for region 8 (Mississippi)</li>
# <li>Select watershed 080902030506</li>
# <li>Generate a site map of the watershed</li>
# </ol>
# <p>Try to use the <strong>caching decorator</strong></p></div></div>
#
# We chose this watershed because it covers parts of New Orleans an is
# near the Mississippi Delta. Deltas are boundary areas between the land
# and the ocean, and as a result tend to contain a rich variety of
# different land cover and land use types.
#
# <link rel="stylesheet" type="text/css" href="./assets/styles.css"><div class="callout callout-style-default callout-response"><div class="callout-header"><div class="callout-icon-container"><i class="callout-icon"></i></div></div><div class="callout-body-container callout-body"><p>Write a 2-3 sentence <strong>site description</strong> (with
# citations) of this area that helps to put your analysis in context.</p></div></div>

# %%
# Pasted URL of watershead boundaries to refer back to if needed
# https://prd-tnm.s3.amazonaws.com/StagedProducts/Hydrography/WBD/HU2/Shape/WBD_08_HU2_Shape.zip

# %%
# Select study site and plot Part 1 of 
# Create function to return a gdf of the watershed boundary data

# Call the decorator function using the @
@cached(
        # The func_key here will be wbd_08
        # this is for region 8 of the watershed boundary data
        'wbd_08')
# Create a new funtion, 3 parameters
def read_wbd_file(
    # Name of file to be downloaded and processed
    wbd_filename, 
    # Level of the data
    huc_level, 
    # Can further refine the cache_key
    cache_key):
    # Download and unzip
    # Define URL
    wbd_url = (
        "https://prd-tnm.s3.amazonaws.com"
        "/StagedProducts/Hydrography/WBD/HU2/Shape/"
        # Insert the name of the specific file wanted using f-string
        f"{wbd_filename}.zip")
    
    # Define, create nested path and dir for watershed boundaries
    # Path for watershed boundaries
    watershed_bd_dir = os.path.join(landcover_cluster_data_dir, 'watershed_bd')
    # Create directory for this path
    os.makedirs(watershed_bd_dir, 
            # If directory already exists no error is raised
            exist_ok=True)
    # Download and unzip the data into the above dir
    watershed_bd_dir = et.data.get_data(url=wbd_url)
                  
    # Read desired data
    # Path to shapefile in dir, subfolder, shapefile
    watershed_bd_path = os.path.join(watershed_bd_dir, 'Shape', f'WBDHU{huc_level}.shp')
    # Read shapefile as a gdf
    watershed_bd_gdf = gpd.read_file(watershed_bd_path, 
        # Use pyogrio library to read shapfile
        engine='pyogrio')
    
    # Return the gdf of the watershed boundaries
    return watershed_bd_gdf

# %%
# Select study site and plot Part 2 of 4
# Apply the read_wbd_file function

# Define the huc_level - 12
huc_level = 12
# Download and open the shapefile
watershed_bd_gdf = read_wbd_file(
    # Name of file to be downlaoded and processed
    "WBD_08_HU2_Shape", 
    # Level of the data
    huc_level, 
    # Refine by huc level
    cache_key=f'hu{huc_level}')

# %%
# Call gdf to see it
watershed_bd_gdf.head()
# Out:
#                                     tnmid  \
# 0  {8AFB1AF9-7296-4303-89DE-14CD073B859A}
# 1  {916A17A6-B4A0-4FD7-9BB8-FFD1936B15B2}
# 2  {493C7EC1-2F1C-4B84-AFFB-6F6868A9868E}
# 3  {49A3C087-B460-4F97-9D99-78CBB675248B}
# 4  {0FB41498-11EA-4AB1-AF05-E2A8E5E2E274}
#
#                                metasource                        sourcedata  \
# 0  {511D2AC8-11BA-45FC-AB98-F69D693D4C44}  Watershed Boundary Dataset (WBD)
# 1  {511D2AC8-11BA-45FC-AB98-F69D693D4C44}  Watershed Boundary Dataset (WBD)
# 2  {511D2AC8-11BA-45FC-AB98-F69D693D4C44}  Watershed Boundary Dataset (WBD)
# 3  {511D2AC8-11BA-45FC-AB98-F69D693D4C44}  Watershed Boundary Dataset (WBD)
# 4  {511D2AC8-11BA-45FC-AB98-F69D693D4C44}  Watershed Boundary Dataset (WBD)
#
#                                           sourceorig sourcefeat   loaddate  \
# 0  Natural Resources and Conservation Service and...       None 2024-08-15
# 1  Natural Resources and Conservation Service and...       None 2024-08-15
# ...

# %%
# Select study site and plot Part 3 of 4

# Define new variable for the plot
ms_delta_gdf = (
    # Filter the to the rows of watershed wanted
    watershed_bd_gdf[watershed_bd_gdf[f'huc{huc_level}']
    # Select watershed 
    .isin(['080902030506'])]
    # Merge geometries of all rows matching this watershed
    .dissolve()
)

# Call the gdf to see it 
ms_delta_gdf.head()
# Out:
#                                             geometry  \
# 0  POLYGON ((-89.97047 29.74687, -89.96593 29.750...
#
#                                     tnmid  \
# 0  {E942B72E-599E-48F5-908A-EA5265701C14}
#
#                                metasource                        sourcedata  \
# 0  {511D2AC8-11BA-45FC-AB98-F69D693D4C44}  Watershed Boundary Dataset (WBD)
#
#                                           sourceorig sourcefeat   loaddate  \
# 0  Natural Resources and Conservation Service and...       None 2024-08-15
#
#       referenceg  areaacres  areasqkm  ...         huc12  \
# 0  536881,539539   37355.86    151.17  ...  080902030506
#
#                         name hutype humod         tohuc noncontrib  \
# 0  Manuel Canal-Spanish Lake      D    GC  080902030508        0.0
#
#    noncontr_1  shape_Leng  shape_Area  ObjectID
# 0         0.0         NaN         NaN      2560
#
# [1 rows x 21 columns]

# %%
# Select study site and plot Part 4 of 4

# Plot site map of the watershed
ms_delta_site_map = (
(
    # Project to Mercator 
    ms_delta_gdf.to_crs(ccrs.Mercator())
    # Plot using hvplot
    .hvplot(
        # Set geometry as slightly transparent and white
        alpha=.3, fill_color='white', 
        # Add ESRI tile background
        tiles='EsriImagery', 
        # Set basemap/background to Mercator to match
        crs=ccrs.Mercator(),
        # Set title
        title='Mississippi River Delta Watershed - Site Map',
        )
    .opts(
        # Size of plot - set width and height
        width=900, height=600)
))

# Save the plot as html to be able to display online
hv.save(ms_delta_site_map, 'chi_chloropleth_asthma_by_tract.html')  

# Display the plot
ms_delta_site_map
# Out:
# :Overlay
#    .WMTS.I     :WMTS   [Longitude,Latitude]
#    .Polygons.I :Polygons   [Longitude,Latitude]

# %% [markdown]
# # Site Description - Mississippi River Delta Watershed site Map
# The Mississippi River Delta is located within the Lower Mississippi Valley (U.S.)
# and has had much prior research done on land cover classes and change
# in land cover classes showing a wide range of types (water, developed,
# mechanically disturbed, mining, barren, forest, grass/shurb, agriculture, wetland)
# due to its location on land and near bodies of water (Karstensen and Sayler, 1-7).
# Historically it had deciduous forests, but after mass tree clearing through the
# 1970's the land use converted to mostly agricultural and aquacultural use
# (Karstensen and Sayler, 1). Thus, these lands are tied to the economy providing
# numerous jobs; these lands are also home to a diversity of habitats for wildlife
# including endangered and threatened species whom are threatened by mass wetland
# loss and climate change (National Wildlife Federation). The watershed drains water
# from a large portion of the contiguous U.S. and eventually into the Gulf of
# Mexico (National Park Service, 2024). This is an important natural process that
# is being disrupted by humans resulting in the the river being disconnected from the
# floodplain (Morris, 2017). There are currently many ongoing efforts to
# restore the delta for pepople, wildlife, and protect from natural disaters (RESTORE
# The Mississippi River Delta). The work being done here is really inspiring and
# important - if you are curious to learn more I reccomend looking at the
# [Restore the Mississippi River Delta website](https://mississippiriverdelta.org) .
# The National Park Service also has a great
# [multifaceted report](https://www.nps.gov/locations/lowermsdeltaregion/the-natural-environment-the-delta-and-its-resources.htm)
# that goes over the history, geology, land uses, endangered and threatened species,
# national wildlife refuges, floods and extraordinary natural events, and challenges
# for the future - this would be a great source for further research and understanding
# the Mississippi River Delta.
#
# The site map above, if you zoom out, you get a better context of truely how
# close this is to the gulf. The latitude ranges less than 1 degree and
# the longitude ranges also around 1 degree. Visually this plot one can
# also see there seems to be elevation changes, a road or dam possibly to
# the left of the outlined area, and different types of land cover. For
# such a contained area it is visually diverse in land cover. It will be
# interesting to use satellite imagery to do analysis here because visually
# it is already diverse and this will only be added to with further analysis.
#
# ## Citations
#
# * Karstensen, K.A., and Sayler, K.L., 2009,
# Land-cover change in the Lower Mississippi Valley, 1973–2000:
# U.S. Geological Survey Open-File Report 2009–1280, 12 p.
# https://pubs.usgs.gov/of/2009/1280/pdf/of2009-1280.pdf
#
# * National Wildlife Federation. 'Mississippi River Delta'.
# https://www.nwf.org/Educational-Resources/Wildlife-Guide/Wild-Places/Mississippi-River-Delta
#
# * National Park Service. 'Mississippi River Facts'.
# Updated December 31, 2024.
# https://www.nps.gov/miss/riverfacts.htm#:~:text=Some%20like%20to%20measure%20the,(2.7%20million%20square%20miles).
#
# * Morris, Christopher. Environmental Science, 'Environmental History of the
# Mississippi River and Delta'. September 26, 2017.
# https://oxfordre.com/environmentalscience/display/10.1093/acrefore/9780199389414.001.0001/acrefore-9780199389414-e-114?p=emailAke4d9oJyr02w&d=/10.1093/acrefore/9780199389414.001.0001/acrefore-9780199389414-e-114#:~:text=The%20Mississippi%20River%20delta%20begins,approach%20to%20Mississippi%20River%20management.
#
# * RESTORE The Mississippi River Delta. 'America Needs the Delta'.
# https://mississippiriverdelta.org
#
#
# * National Park Service -  Lower Mississippi Delta Region.
# 'The Natural Environment: The Delta and Its Resources'.
# Updated November 16, 2017.
# https://www.nps.gov/locations/lowermsdeltaregion/the-natural-environment-the-delta-and-its-resources.htm
#
#
# * Watershed Boundary Dataset About- https://www.usgs.gov/national-hydrography/access-national-hydrography-products

# %% [markdown]
# ## STEP 3: MULTISPECTRAL DATA
#
# ### Search for data
#
# <link rel="stylesheet" type="text/css" href="./assets/styles.css"><div class="callout callout-style-default callout-titled callout-task"><div class="callout-header"><div class="callout-icon-container"><i class="callout-icon"></i></div><div class="callout-title-container flex-fill">Try It</div></div><div class="callout-body-container callout-body"><ol type="1">
# <li>Log in to the <code>earthaccess</code> service using your Earthdata
# credentials:
# <code>python      earthaccess.login(persist=True)</code></li>
# <li>Modify the following sample code to search for granules of the
# HLSL30 product overlapping the watershed boundary from May to October
# 2023 (there should be 76 granules):
# <code>python      results = earthaccess.search_data(          short_name="...",          cloud_hosted=True,          bounding_box=tuple(gdf.total_bounds),          temporal=("...", "..."),      )</code></li>
# </ol></div></div>

# %%
# Wrangle raster data Part 1 of 4

# Log in to earthaccess
earthaccess.login(
    # Prompt to input login credentials
    strategy = "interactive", 
    # Remember credentials
    persist = True)

# Search for HLS tiles
hls_results = earthaccess.search_data(
    # Filter search for data only related to HLS30
    # HLS30 is Harmonized Landsat Sentinal data 30m resolution
    short_name = "HLSL30",
    # Only return cloud hosted data
    cloud_hosted = True,
    # Set spatial bounds
    # Convert bounding box into tuple format for the search
    bounding_box = tuple(
        # Give min and max geogrpahic bounds of the gdf
        ms_delta_gdf.total_bounds),
    # Set temporal bounds
    temporal=("2024-06", "2024-08")
)

# Call the variable to see if that worked
hls_results
# Out:
# [Collection: {'EntryTitle': 'HLS Landsat Operational Land Imager Surface Reflectance and TOA Brightness Daily Global 30m v2.0'}
#  Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'GPolygons': [{'Boundary': {'Points': [{'Longitude': -89.79864173, 'Latitude': 29.70347853}, {'Longitude': -89.76643746, 'Latitude': 30.69278312}, {'Longitude': -90.91181412, 'Latitude': 30.71627038}, {'Longitude': -90.93262544, 'Latitude': 29.72659663}, {'Longitude': -89.79864173, 'Latitude': 29.70347853}]}}]}}}
#  Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-06-07T16:31:11.509Z', 'EndingDateTime': '2024-06-07T16:31:11.509Z'}}
#  Size(MB): 169.50417041778564
# ...

# %% [markdown]
# ### Compile information about each granule
#
# I recommend building a GeoDataFrame, as this will allow you to plot the
# granules you are downloading and make sure they line up with your
# shapefile. You could also use a DataFrame, dictionary, or a custom
# object to store this information.
#
# <link rel="stylesheet" type="text/css" href="./assets/styles.css"><div class="callout callout-style-default callout-titled callout-task"><div class="callout-header"><div class="callout-icon-container"><i class="callout-icon"></i></div><div class="callout-title-container flex-fill">Try It</div></div><div class="callout-body-container callout-body"><ol type="1">
# <li>For each search result:
# <ol type="1">
# <li>Get the following information (HINT: look at the [‘umm’] values for
# each search result):
# <ul>
# <li>granule id (UR)</li>
# <li>datetime</li>
# <li>geometry (HINT: check out the shapely.geometry.Polygon class to
# convert points to a Polygon)</li>
# </ul></li>
# <li>Open the granule files. I recomment opening one granule at a time,
# e.g. with (<code>earthaccess.open([result]</code>).</li>
# <li>For each file (band), get the following information:
# <ul>
# <li>file handler returned from <code>earthaccess.open()</code></li>
# <li>tile id</li>
# <li>band number</li>
# </ul></li>
# </ol></li>
# <li>Compile all the information you collected into a GeoDataFrame</li>
# </ol></div></div>

# %%
# Wrangle raster data Part 2 of 4

# Create function to compile temporal and spatial 
# information about each granule in gdfs
def get_earthaccess_links(results):
    """
            Compile spatial and temporal info from granules into gdfs
            
            Parameters
            ==========
            results: list
              list of files 
            
            """
    # Comppile a regular expression pattern into an object
    url_re = re.compile(
        # Create a regular expression
        r'\.(?P<tile_id>\w+)\.\d+T\d+\.v\d\.\d\.(?P<band>[A-Za-z0-9]+)\.tif')

    # Loop through each granule
    # Create empty list to save gdfs to
    link_rows = []
    # Create empty list to save the url dfs to
    url_dfs = []
    # Start for loop
    # Have loop iterate through each granule in results
    # Wrap results iterable in tqdm which displays progress bar
    for granule in tqdm(results):
        # Get granule information
        # Get metadata info from each granule stored in the umm key for each granule
        info_dict = granule['umm']
        # Extract Granule Univeral Resource (UR) 
        # This is an identifier for each granule
        granule_id = info_dict['GranuleUR']
        # Extract datetime into pd object
        # This helps with extracting specific parts like year, month, day
        # Or calculating time difference or sorting/filtering by dates
        datetime = pd.to_datetime(
            # From the metadata of the granule
            info_dict
            # Extract temporal information using columns:
            ['TemporalExtent']['RangeDateTime']['BeginningDateTime'])
        # Extract boundary points of granule's spatial extent
        points = (
            # From the metadata of the granule
            info_dict
            # Extract spatial information using columns:
            ['SpatialExtent']['HorizontalSpatialDomain']['Geometry']['GPolygons'][0]
            ['Boundary']['Points'])
        # Create polygon object
        geometry = Polygon(
            # Take lon lat pairs from the points above to construct a polygon
            # that represents the granule's spatial boundary
            [(point['Longitude'], point['Latitude']) for point in points])
        
        # Open granule files
        files = earthaccess.open([granule])

        # Build metadata DataFrame
        for file in files:
            # Apply regular expression
            match = url_re.search(
                # to the file.full_name
                file.full_name)
            # Conditional statement
            # If match is found, this code block will execute
            if match is not None:
                # Each time a gdf is created append to the link_rows list
                link_rows.append(
                    # Create new gdf
                    gpd.GeoDataFrame(
                        # Create a dictionary with keys as columns
                        dict(
                            # Column names:
                            # Extract datetime from file name
                            datetime=[datetime],
                            # Extract tile id from file name
                            tile_id=[match.group('tile_id')],
                            # Extract band from file name
                            band=[match.group('band')],
                            # Full url/file path of the data file
                            url=[file],
                            # Extract geomentry from the file
                            geometry=[geometry]
                        ),
                        # Specify CRS for gdf based on lat lon
                        crs="EPSG:4326"
                    )
                )

    # Concatenate metadata DataFrame
    # Concatenate list of gdfs from link_rows
    file_df = pd.concat(
        # Reset index to a default integer index
        # This is because each gdf might have its own index which would
        # make it hard to continue doing analysis on the data otherwise
        link_rows).reset_index(
            # Drop the old index column
            # This keeps the old index column from being
            # added as an additional column 
            drop=True)
    # Return file_df which is the concatenated, reset list of gdfs created
    return file_df

# %% [markdown]
# ### Open, crop, and mask data
#
# This will be the most resource-intensive step. I recommend caching your
# results using the `cached` decorator or by writing your own caching
# code. I also recommend testing this step with one or two dates before
# running the full computation.
#
# This code should include at least one **function** including a
# numpy-style docstring. A good place to start would be a function for
# opening a single masked raster, applying the appropriate scale
# parameter, and cropping.
#
# <link rel="stylesheet" type="text/css" href="./assets/styles.css"><div class="callout callout-style-default callout-titled callout-task"><div class="callout-header"><div class="callout-icon-container"><i class="callout-icon"></i></div><div class="callout-title-container flex-fill">Try It</div></div><div class="callout-body-container callout-body"><ol type="1">
# <li>For each granule:
# <ol type="1">
# <li><p>Open the Fmask band, crop, and compute a quality mask for the
# granule. You can use the following code as a starting point, making sure
# that <code>mask_bits</code> contains the quality bits you want to
# consider: ```python # Expand into a new dimension of binary bits bits =
# ( np.unpackbits(da.astype(np.uint8), bitorder=‘little’)
# .reshape(da.shape + (-1,)) )</p>
# <p># Select the required bits and check if any are flagged mask =
# np.prod(bits[…, mask_bits]==0, axis=-1) ```</p></li>
# <li><p>For each band that starts with ‘B’:</p>
# <ol type="1">
# <li>Open the band, crop, and apply the scale factor</li>
# <li>Name the DataArray after the band using the <code>.name</code>
# attribute</li>
# <li>Apply the cloud mask using the <code>.where()</code> method</li>
# <li>Store the DataArray in your data structure (e.g. adding a
# GeoDataFrame column with the DataArray in it. Note that you will need to
# remove the rows for unused bands)</li>
# </ol></li>
# </ol></li>
# </ol></div></div>

# %%
# Wrangle raster data Part 3 of 4

# Call the decorator function using the @
@cached(
        # The func key or basename of file to save results to
        'delta_reflectance_da_df')
# Create new function to loop through each image, name da after the band, 
# apply the cloud mask, and store da by adding it as column in gdf, then concatenate
def compute_reflectance_da(search_results, boundary_gdf):
    """
    Connect to files over VSI, crop, cloud mask, and wrangle
    
    Returns a single reflectance DataFrame 
    with all bands as columns and
    centroid coordinates and datetime as the index.
    
    Parameters
    ==========
    file_df (search results) : pd.DataFrame
        File connection and metadata (datetime, tile_id, band, and url)
    boundary_gdf : gpd.GeoDataFrame
        Boundary use to crop the data
    """
     # Create new function to crop raster
    def open_dataarray(url, boundary_proj_gdf, scale=1, masked=True):
        """
        Open masked da, reproject CRS, and crop raster image
        
        Returns a cropped raster

        Parameters
        ==========
        url: 
            the url to the raster image(s)
        boundary_proj_gdf: gpd.GeoDataFrame
            Boundary used to crop the data
        scale=1: int
            Scale factor to apply to the pixel values
        masked=True: bool
            Whether to mask the invalid or missing data
        """
        # Open masked DataArray
        # Create variable for da, open raster file
        da = rxr.open_rasterio(
            # located at the url
            url,
            # ignore invlaid or missing data in calculations (masked=True)
            masked=masked
            # Remove single dimensional axes from da to convert into scalar values
            ).squeeze(
            # Multiply all pixel values in the da by a scaling factor   
            ) * scale
        
        # Reproject boundary if needed
        # Check if boundary was already reprojected
        if boundary_proj_gdf is None:
            # If it hasn't been, reproject into CRS of raster data (da)
            boundary_proj_gdf = boundary_gdf.to_crs(da.rio.crs)
            
        # Crop raster using the boundary
        # Use coordinates from total bounds to clip the raster image(s)
        # to the area defined by the boundary
        cropped = da.rio.clip_box(
            # Provide the bounding box of boundary's extent 
            # (mix, miny, maxx, maxy) via .total_bounds
            *boundary_proj_gdf.total_bounds)

        # Return cropped version of the raster
        return cropped
    
    
    # Create function to mask raster
    def compute_quality_mask(da, mask_bits=[1, 2, 3]):
        """
        Mask out low quality data by bit
        
        Returns masked raster

        Parameters
        ==========
        da: xarray.DataArray
            Raster data (to apply the mask to)
        mask_bits[]: list of integers (optional)
            List of bits positions that correspond to low-quality flags in the data 
            when these bits match these positions, the function will mask/ exclude 
            those values (clouds, cloud shadow, etc.) default is [1,2,3]
        """
        # Unpack bits into a new axis
        bits = (
            # Takes 8 bit values and unpack into individual bits
            np.unpackbits(
                # Cast the input raster data (da) into 8 bit unassigned integers 
                # so that data is in a format that can be unpacked into individual bits
                da.astype(np.uint8), 
                # Specify bit order, least significant bit at position 0
                bitorder='little'
            # Reshape resulting bit array to match the shape of the original 
            # raster (da) a 3D array format, and add new axis for unpacked bits
            ).reshape(da.shape + (-1,))
        )

        # Select the required bits and check if any are flagged
        mask = np.prod(
            # Select specific bit positions, create boolean mask
            bits[..., mask_bits]==0,
            # Compute product of the elements along the chosen axis
            # here chose the last axis of the array which is signaled 
            # using '-1'. 
            axis=-1)
        # Return mask, which is binary where True/1 means the pixel 
        # is high quality versus False/0 means the pixel is low quality
        return mask

    # Create new variable for file df using get_earthaccess_links function
    # to compile temporal and spatial information about each granule in gdfs
    file_df = get_earthaccess_links(search_results)
    # Creat empty list to save back to
    granule_da_rows= []
    # Create placeholder for variable name/ clear references to objects
    boundary_proj_gdf = None

    # Loop through each image
    # Create new variable to - Group file_df by the columns 'datetime' 
    # and 'tile_id'. This will create a subset of data for each unique combo 
    # of datetime and tile_id
    group_iter = file_df.groupby(['datetime', 'tile_id'])
    # Loop through each group of datetime tile_id unique combos
    # to provide a tuple containing the datetime and tile_id
    # Use tqdm function for progress bar
    for (datetime, tile_id), granule_df in tqdm(group_iter):
        # Print message to show which granule is being processed 
        # based on tile_id and datetime
        print(f'Processing granule {tile_id} {datetime}')
              
        # Open granule cloud cover
        # Create new variable for the cloud mask url
        cloud_mask_url = (
            # Extract the cloud mask - band name is 'Fmask' 
            # from the granule_df 
            granule_df.loc[granule_df.band=='Fmask', 'url']
            #
            .values[0])
        # Open cloud mask data,
        cloud_mask_cropped_da = open_dataarray(
            # Using boundary_proj_gdf as the spatial boundary cropping the data
            cloud_mask_url, boundary_proj_gdf, 
            # Do not mask data initially
            masked=False)

        # Compute cloud mask
        # Create new variable to apply the quality mask to 
        # identify which pixels are valid (not low quality)
        cloud_mask = compute_quality_mask(cloud_mask_cropped_da)

        # Loop through each spectral band
        # Create empty list to store da's
        da_list = []
        # Create empty list to store df rows
        df_list = []
        # Loop through each row (spectral band) in granule_df
        for i, row in granule_df.iterrows():
            # If the spectral band name starts with 'B' ...
            if row.band.startswith('B'):
                # Open, crop, and mask the band
                band_cropped = open_dataarray(
                    # retrieve url for the band from the row
                    row.url, 
                    # based pn the boundary_proj_gdf
                    boundary_proj_gdf, 
                    # Scale pixel values to proper unit (reflectance)
                    scale=0.0001)
                # Set band name
                band_cropped.name = row.band
                # Add the DataArray to the metadata DataFrame row
                # and apply cloud mask using .where() - returns only 
                # non masked pixels
                row['da'] = band_cropped.where(cloud_mask)
                # Accumulate all processed rows for the granule
                granule_da_rows.append(
                    # Convert row to df
                    row.to_frame().T)
    
    # Reassemble the metadata DataFrame
    return pd.concat(granule_da_rows)

# Apply the 'compute reflectance da' function

# Create new data array df using the compute_reflectance_da 
# function to connect to files over VSI, crop, cloud mask, 
# and wrangle data
reflectance_da_df = compute_reflectance_da(
    # List of HLS files that are bounded by geographic 
    # bounds of the ms_delta_gdf
    hls_results,
    # Mississippi River Delta watershed boundary gdf
    ms_delta_gdf)

# %%
# Call reflectance_da_df to see it
reflectance_da_df.head()
# Out:
#                             datetime tile_id band  \
# 45  2024-06-07 16:31:11.509000+00:00  T15RYN  B04
# 48  2024-06-07 16:31:11.509000+00:00  T15RYN  B06
# 49  2024-06-07 16:31:11.509000+00:00  T15RYN  B03
# 50  2024-06-07 16:31:11.509000+00:00  T15RYN  B07
# 51  2024-06-07 16:31:11.509000+00:00  T15RYN  B02
#
#                                                   url  \
# 45  <File-like object HTTPFileSystem, https://data...
# 48  <File-like object HTTPFileSystem, https://data...
# 49  <File-like object HTTPFileSystem, https://data...
# 50  <File-like object HTTPFileSystem, https://data...
# 51  <File-like object HTTPFileSystem, https://data...
#
#                                              geometry  \
# 45  POLYGON ((-89.82661214 28.80213717, -89.795837...
# 48  POLYGON ((-89.82661214 28.80213717, -89.795837...
# 49  POLYGON ((-89.82661214 28.80213717, -89.795837...
# 50  POLYGON ((-89.82661214 28.80213717, -89.795837...
# 51  POLYGON ((-89.82661214 28.80213717, -89.795837...
#
# ...

# %% [markdown]
# ### Merge and Composite Data
#
# You will notice for this watershed that: 1. The raster data for each
# date are spread across 4 granules 2. Any given image is incomplete
# because of clouds
#
# <link rel="stylesheet" type="text/css" href="./assets/styles.css"><div class="callout callout-style-default callout-titled callout-task"><div class="callout-header"><div class="callout-icon-container"><i class="callout-icon"></i></div><div class="callout-title-container flex-fill">Try It</div></div><div class="callout-body-container callout-body"><ol type="1">
# <li><p>For each band:</p>
# <ol type="1">
# <li><p>For each date:</p>
# <ol type="1">
# <li>Merge all 4 granules</li>
# <li>Mask any negative values created by interpolating from the nodata
# value of -9999 (<code>rioxarray</code> should account for this, but
# doesn’t appear to when merging. If you leave these values in they will
# create problems down the line)</li>
# </ol></li>
# <li><p>Concatenate the merged DataArrays along a new date
# dimension</p></li>
# <li><p>Take the mean in the date dimension to create a composite image
# that fills cloud gaps</p></li>
# <li><p>Add the band as a dimension, and give the DataArray a
# name</p></li>
# </ol></li>
# <li><p>Concatenate along the band dimension</p></li>
# </ol></div></div>

# %%
# Wrangle raster data Part 4 of 4

# Call decorater function using @
@cached('delta_reflectance_da')

# Create new function to 
def merge_and_composite_arrays(granule_da_df):
    """
    Merge and composite and image for each band 
    and composite images across dates
    
    Returns merged and composite dataset into a single da
    
    Parameters
    ==========
    granule_da_df : xarray.DataArray, pd.DataFrame
       Multidimensional array /File connection and metadata
    """
    # Merge and composite an image for each band
    # Create empty list to store df's
    df_list = []
    # Create empty list to store composited da's
    da_list = []
    # Loop through each spectral band
    # Use tqdm function to show progress bar
    for band, band_df in tqdm(granule_da_df.groupby('band')):
        # Create empty list to store merged images for all dates
        merged_das = []
        # Loop through each date group to merge granules for that date
        # Use tqdm function to show progress bar
        # Group band_df by datetime column
        for datetime, date_df in tqdm(band_df.groupby('datetime')):
            # Merge granules for each date into a single da representing the 
            #merged image for that date
            merged_da = rxrmerge.merge_arrays(list(date_df.da))
            # Mask negative values - removes neg values from the merged da
            merged_da = merged_da.where(merged_da>0)
            # Append this merged and cleaned da to to merged_das which 
            # holds the merged images for all dates
            merged_das.append(merged_da)
            
        # Composite images across dates
        composite_da = xr.concat(merged_das, dim='datetime').median('datetime')
        # Extract band number from the band string and convert into an integer
        composite_da['band'] = int(band[1:])
        # Name the composite_da 'reflectance'
        composite_da.name = 'reflectance'
        # Append composited da to the da_list
        da_list.append(composite_da)

    # Return final merged and composited dataset
    # Concatenate all composited da's along the band dimension using 
    # xr.concat, resulting in a single da
    return xr.concat(da_list, dim='band')

# Create new variable to use the merge_and_composite_arrays function
reflectance_da = merge_and_composite_arrays(reflectance_da_df)
# Call the variable to see it
reflectance_da
# Out:
# <xarray.DataArray 'reflectance' (band: 10, y: 556, x: 624)> Size: 14MB
# array([[[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
# ...
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
# ...

# %% [markdown]
# ## STEP 4: K-MEANS
#
# Cluster your data by spectral signature using the k-means algorithm.
#
# <link rel="stylesheet" type="text/css" href="./assets/styles.css"><div class="callout callout-style-default callout-titled callout-task"><div class="callout-header"><div class="callout-icon-container"><i class="callout-icon"></i></div><div class="callout-title-container flex-fill">Try It</div></div><div class="callout-body-container callout-body"><ol type="1">
# <li>Convert your DataArray into a <strong>tidy</strong> DataFrame of
# reflectance values (hint: check out the <code>.to_dataframe()</code> and
# <code>.unstack()</code> methods)</li>
# <li>Filter out all rows with no data (all 0s or any N/A values)</li>
# <li>Fit a k-means model. You can experiment with the number of groups to
# find what works best.</li>
# </ol></div></div>

# %%
# Convert spectral DataArray to a tidy DataFrame
model_df = reflectance_da.to_dataframe(
    # Select the reflectance column from the df
    # Reshape the df - create new column for each band and each 
    # row would correspond to a spatial location/pixel in the image
    ).reflectance.unstack('band')
# Overwrite model_df to drop
model_df = model_df.drop(
    # Columns 10 and 11 because they are not needed
    columns=[10, 11]
    #  and remove NaN values
    ).dropna()

# Running the fit and predict functions at the same time.
# We can do this since we don't have target data.
prediction = KMeans(
    # use 6 clusters
    n_clusters=6
    # Fits model to data, then predicts the cluster for each row
    ).fit_predict(
        # Retrieve all values stored in the model_df
        model_df.values)

# Add the predicted values back to the model DataFrame
model_df['clusters'] = prediction
# Call the variable to see it
model_df
# Out:
# band                              1       2       3       4       5       6  \
# y            x
# 3.303783e+06 810148.062907  0.01560  0.0225  0.0409  0.0366  0.0478  0.0281
#              810178.062907  0.01895  0.0256  0.0396  0.0413  0.0426  0.0284
#              810208.062907  0.01915  0.0246  0.0387  0.0377  0.0384  0.0273
#              810238.062907  0.02040  0.0247  0.0440  0.0445  0.0629  0.0418
#              810268.062907  0.01815  0.0245  0.0437  0.0444  0.0618  0.0397
# ...                             ...     ...     ...     ...     ...     ...
# 3.287163e+06 793768.062907  0.02650  0.0345  0.0548  0.0427  0.0218  0.0098
#              793798.062907  0.02790  0.0351  0.0549  0.0439  0.0221  0.0104
#              793828.062907  0.02580  0.0331  0.0534  0.0419  0.0194  0.0080
#              793858.062907  0.02570  0.0326  0.0521  0.0402  0.0182  0.0064
#              793888.062907  0.02550  0.0340  0.0541  0.0423  0.0199  0.0083
#
# ...

# %%
# K Means Part 2 of 

# Visulaize current clusters by using pairplots
sns.pairplot(model_df)

# %%
# Try tuning the hyperparameter via silhoutette scores

# Accumulate silhouette scores
# Make an empty list to accumulate to
silhouette = []
# Make a list of K values to loop through, try 2 through 8
k_list_values = list(range(2,8))
# Loop through K values, use tqdm to wrap around loop to see progress bar
for k in tqdm(k_list_values, desc="KMeans Progress", ncols=100):
    # Make model with K clusters
    k_means = KMeans(n_clusters = k,
    # Fits model to data
    ).fit(
        # Retrieve all values stored in the model_df
        model_df.values)
    
    # Add cluster labels to df
    model_df['k_means_labels'] = k_means.labels_
    # Calculate silhouette score
    score = silhouette_score(model_df.values, k_means.labels_)

    # Calculate silhouette score and add it to list initialized 
    # with corresponding K values
    silhouette.append(score)

# Print silhouette scores for each k value
#print(silhouette)
# Out:
# KMeans Progress:   0%|                                                        | 0/7 [00:00<?, ?it/s]

# %%
# Visualize silhouette scores as a scatterplot
sns.scatterplot(
    # Set x axis equal to the k_list_values
    x = k_list_values,
    # Set the y axis equal to the silhouette scores
    y = silhouette
)
# Set the title using matplotlib
plt.title('Silhouette Scores vs. Number of Clusters')

# Set axis labels
# Label for the x-axis
plt.xlabel('Number of Clusters (k)')  
# Label for the y-axis
plt.ylabel('Silhouette Score')        

# Save as a jpg
plt.savefig('silhouette_scores_vs_clusters.jpg') 

# Show plot
plt.show()

# %% [markdown]
# ## STEP 5: PLOT
#
# <link rel="stylesheet" type="text/css" href="./assets/styles.css"><div class="callout callout-style-default callout-titled callout-task"><div class="callout-header"><div class="callout-icon-container"><i class="callout-icon"></i></div><div class="callout-title-container flex-fill">Try It</div></div><div class="callout-body-container callout-body"><p>Create a plot that shows the k-means clusters next to an RGB image of
# the area. You may need to brighten your RGB image by multiplying it by
# 10. The code for reshaping and plotting the clusters is provided for you
# below, but you will have to create the RGB plot yourself!</p>
# <p>So, what is <code>.sortby(['x', 'y'])</code> doing for us? Try the
# code without it and find out.</p></div></div>

# %%
# Plot the k-means clusters

# Create da with just rgb bands selected
rgb = reflectance_da.sel(band=[4, 3, 2])
# Change pixel values to 8 bit integers with range from 0-255
# instead of 0-1 like the scale of the reflectance values
rgb_uint8 = (rgb * 255
    # Convert type
    ).astype(np.uint8
    # Take out NaN values
    ).where(rgb!=np.nan)
# Increase brightness of the image so it's not so dark
rgb_bright = rgb_uint8 * 10
# When rgb value is saterated, if value is 255 keep that value,
# if value greater than 255, replace with 255
rgb_sat = rgb_bright.where(rgb_bright < 255, 255)

# Retrieve the CRS of the raster data (if it's set)
# Assuming `rgb_sat` has the same CRS as `reflectance_da`
# Assuming the CRS is stored in rasterio's CRS
#raster_crs = reflectance_da.rio.crs 

# Reproject watershed boundary to match the raster CRS
#ms_delta_gdf = ms_delta_gdf.to_crs(raster_crs)

# Create variable name for plots in order to save later
true_color_and_landcover_cluster_plots = (
#true_color_image = (
    # Plot using hvplot and .rgb method
    rgb_sat.hvplot.rgb( 
        # Tell .rgb method to set the x axis = x, y axis = y,
        # and bands = 'band'
        x ='x', y ='y', bands = 'band',
        # Avoid distortion
        data_aspect=1,
        # Drop the axes
        xaxis = None, yaxis = None,
        # Set width and height
        width=600, height=600, 
        # Set title
        title = 'Mississippi River Delta - True Color Image')

    # Add watershed boundary to the true color image
    #+ ms_delta_gdf.hvplot(
        # Set line color
        #color = 'orange',
        # Set line width
        #line_width = 3,
        #geo = raster_crs
    #)
#)
+
#landcover_clusters_plot = (
    # Plot clusters, make into xarray
    model_df.clusters.to_xarray(
        # Tell how things are supposed to be realted to each other in the array
        ).sortby(['x', 'y']).hvplot(
        # Set color palette/scheme to colorblind
        cmap = "Colorblind", 
        # Scale the x and y axis the same (helps prevent distortion)
        aspect = 'equal',
        # Drop the axes
        xaxis = None, yaxis = None,
        # Set width and height
        width=600, height=600, 
        # Set title
        title = 'Mississippi River Delta - Land Cover Clusters')

    # Add watershed boundary to the cluster image    
    #+ ms_delta_gdf.hvplot(
        # Set line color
        #color = 'orange',
        # Set line width
        #line_width = 3
    #)
)

# Create new variable name to save both images/plots back to 
#true_color_and_landcover_cluster_plots = true_color_image + landcover_clusters_plot

# Save the plot as html to be able to display online
hv.save(true_color_and_landcover_cluster_plots, 'ms_river_delta_side_by_sides.html')  

# Display the plot
true_color_and_landcover_cluster_plots
# Out:
# :Layout
#    .RGB.I   :RGB   [x,y]   (R,G,B)
#    .Image.I :Image   [x,y]   (clusters)

# %%
# Was having issues plotting boundary
# Look at type of rgb_sat

type(rgb_sat)
# Out:
# xarray.core.dataarray.DataArray

# %%
# Look at type ms_delta_gdf
type(ms_delta_gdf)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %% [markdown]
# <link rel="stylesheet" type="text/css" href="./assets/styles.css"><div class="callout callout-style-default callout-titled callout-respond"><div class="callout-header"><div class="callout-icon-container"><i class="callout-icon"></i></div><div class="callout-title-container flex-fill">Reflect and Respond</div></div><div class="callout-body-container callout-body"><p>Don’t forget to interpret your plot!</p></div></div>

# %% [markdown]
# # Many land cover types present - Clusters seem appropriate when comparing to True Color Image
#
# When comparing both the True Color image and the cluster visualization,
# the number of clusters seems roughly appropriate. There are a wide range of
# green shades on the True Color Image and in the clustering visualization
# areas like the left third of the image, capture mainly (3),
# and (1) clusters with some (5). This captures what is visually
# being seen as different land cover types in the true color image. It is possible
# however that there are too many clusters, visually not much of the yellow, green,
# or dark orange/red can be picked up on visually in the cluster visualization unless
# zoomed in on. So, it would be worth exploring if fewer clusters would aid in
# visualization.
#
# Using 6 clusters was the number in the soultions page, but after calculating
# and visualizing silhouette scores, the determination was made to keep 6 as the
# number of clusters for the model_df. The highest silhouette score was associated with 6,
# but in theory 5-8 could have been chosen as well based on preference.
#
# Going back to the plots themselves, I tried adding a layer to the plots to have
# the boundary of the watershed boundary on both of the plots and couldn't figure it out.
# I have a feeling it is something to do with the projection/CRS. When I look at the da
# for the rgb_sat I know it's a da, and if I drop the axes labels on the plots I can tell
# it's not lat lon, but I also don't think it's Mercator. Those coordinates on these plots
# were seen back in the Merge and Composite Data step of wrangling the raster data. I know I
# need both the gdf and the da in the same CRS for them to be able to plot nicely together,
# but I couldn't figure out how to reproject the gdf to the da's CRS. If I were to continue
# working on this, I would try to figure out how to plot the boundary on those plots because
# I think it would be helpful in analysis. I have also pondered maybe what I'm trying to do
# isn't possible or would take way more effort that it's actually worth; however I am curious d
# if it is possible and what that would take to do it. I would also be interested in looking
# at the elevation here for further analysis.
#
# Overall, the cluster visualization does line up with the research done earlier in
# the notebook to look at the site of the Mississippi River Delta. The research
# on the study area had indicated that the Mississippi River Delta has many different
# landcover types in a relatively small area.
# The [USGS report on 'Land-cover change in the Lower Mississippi
# Valley'](https://pubs.usgs.gov/of/2009/1280/pdf/of2009-1280.pdf) had .
# There are tables in there of estimated land cover types - 10 are listed but only
# 8 appear to have any % of sq km associated with them. This is why a range of 2-8
# clusters for the elbow plot were chosen. While there may be that many estimated land
# cover types present, because this is unsupervised classification it is difficult to asses
# the accuracy of the land cover groups. This is a limitation of this analysis. For
# example, K Means could be picking up agriculture and grass/ shrub as the same thing
# if their spectral signatures are similar and then they are clustered in the same
# group; or it's possible K Means is seperating or creating a cluster for a land
# cover type not all that different from another. So, all that is to say that there
# cannot be definitve statements made about what each cluster is.
#
# Despite the limitations of the analysis doing K Means clustering is helpful
# in understanding that there are broadly grouped categories of land cover types
# here that are different from one another like water vs. forest, or barren.
# Even not knowing was each cluster is, is still helpful because there are many
# different habitats in this general area, in each of the land cover types and
# it's important for conservation and restoration efforts knowing the current
# land cover types so it can be tracked how it changes over time or if
# conservation/resoration efforts are having an effect on the land cover. This is a
# solid base for even further analysis and research.
#
# ## Citations
#
# * Karstensen, K.A., and Sayler, K.L., 2009,
# Land-cover change in the Lower Mississippi Valley, 1973–2000:
# U.S. Geological Survey Open-File Report 2009–1280, 12 p.
# https://pubs.usgs.gov/of/2009/1280/pdf/of2009-1280.pdf
